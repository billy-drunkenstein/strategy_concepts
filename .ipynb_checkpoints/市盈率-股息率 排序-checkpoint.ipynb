# %%
import pandas as pd
import numpy as np
import datetime
import json
import os
from IPython.display import display_html

# %%
def display_horizontal(*args):
    html_str = ''
    for df in args:
        html_str += df.to_html()
    display_html(
        html_str.replace('table','table style="display:inline;margin-right:50px"'), 
        raw=True
    )

# %%
with open("INDEX_START.json", "r", encoding="utf-8") as f:
    INDEX_START = json.load(f)
    
with open("INDEX_NAME.json", 'r', encoding = 'utf-8') as f:
    INDEX_NAME = json.load(f)

# %%
INDEX_DATA = {}

for ticker in INDEX_START:
    path = f"Data/{ticker}.csv"
    
    if os.path.isfile(path): 
        data = pd.read_csv(path, index_col = 0, parse_dates = True)
        INDEX_DATA[ticker] = data.copy(deep = True)
        
len(INDEX_DATA)
# Out:
# 66

# %%
UNIVERSE = {}

for ticker in INDEX_DATA:
    if datetime.datetime(2025, 2, 18) in INDEX_DATA[ticker].index:
        UNIVERSE[ticker] = INDEX_DATA[ticker].copy(deep = True)

# %%
print(f"Assets under Analysis: {len(UNIVERSE)}")
print(f"Total Assets: {len(INDEX_DATA)}")
# Out:
# Assets under Analysis: 66
# Total Assets: 66

# %% [markdown]
# ## Z Score Calculation

# %%
Z_PE_TTM = {}
Z_DIVIDENDYIELD = {}
target_date = datetime.datetime(2025, 2, 18)
years = 5
duration = years * 250

for ticker in UNIVERSE:
    if len(UNIVERSE[ticker]) < duration:
        continue
    
    # PE TTM 分位值
    sample_data = UNIVERSE[ticker]['PE_TTM'].loc[:target_date].iloc[-duration:]
    assert len(sample_data) == duration
    
    mean = sample_data.mean()
    std = sample_data.std()
    
    Z = (UNIVERSE[ticker].loc[target_date, "PE_TTM"] - mean) / std
    
    Z_PE_TTM[ticker] = Z
    
    
    # 股息率 分位值
    sample_data = UNIVERSE[ticker]['DIVIDENDYIELD2'].loc[:target_date].iloc[-duration:]
    assert len(sample_data) == duration
    
    mean = sample_data.mean()
    std = sample_data.std()
    
    Z = (UNIVERSE[ticker].loc[target_date, 'DIVIDENDYIELD2'] - mean) / std
    
    Z_DIVIDENDYIELD[ticker] = Z

# %%
display_number = 20

df_Z_PE_TTM = pd.DataFrame(list(Z_PE_TTM.items()), columns=['Ticker', 'PE_TTM'])
df_Z_DIVIDENDYIELD = pd.DataFrame(list(Z_DIVIDENDYIELD.items()), columns=['Ticker', 'DIVIDENDYIELD'])

# Sort the dataframes
df_Z_PE_TTM_sorted = df_Z_PE_TTM.sort_values(by='PE_TTM', ascending=True)
df_Z_DIVIDENDYIELD_sorted = df_Z_DIVIDENDYIELD.sort_values(by='DIVIDENDYIELD', ascending=False)

# Display the top 10 sorted rows
top_Z_PE_TTM = df_Z_PE_TTM_sorted.head(display_number)
top_Z_DIVIDENDYIELD = df_Z_DIVIDENDYIELD_sorted.head(display_number)

top_Z_PE_TTM.loc[:, "Name"] = top_Z_PE_TTM["Ticker"].map(INDEX_NAME)
top_Z_PE_TTM = top_Z_PE_TTM[["Ticker", "Name", "PE_TTM"]]

top_Z_DIVIDENDYIELD.loc[:, "Name"] = top_Z_DIVIDENDYIELD["Ticker"].map(INDEX_NAME)
top_Z_DIVIDENDYIELD = top_Z_DIVIDENDYIELD[["Ticker", "Name", "DIVIDENDYIELD"]]
# Out:
# /var/folders/wc/s3v7045n4fz9_4bmb56bprdw0000gp/T/ipykernel_327/2912958680.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_Z_PE_TTM.loc[:, "Name"] = top_Z_PE_TTM["Ticker"].map(INDEX_NAME)
# /var/folders/wc/s3v7045n4fz9_4bmb56bprdw0000gp/T/ipykernel_327/2912958680.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_Z_DIVIDENDYIELD.loc[:, "Name"] = top_Z_DIVIDENDYIELD["Ticker"].map(INDEX_NAME)

# %%
print()
print(INDEX_DATA['000300.SH'].index[-1].strftime("%Y-%m-%d"))
print(f"{years} years")
display_horizontal(top_Z_PE_TTM, top_Z_DIVIDENDYIELD)
print()
# Out:
# 2025-03-04
# 5 years
# <table style="display:inline;margin-right:50px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ticker</th>
#       <th>Name</th>
#       <th>PE_TTM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>29</th>
#       <td>707717L.MI</td>
#       <td>MSCI中国A股质量</td>
#       <td>-1.074283</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>H30533.CSI</td>
#       <td>中概互联网</td>
#       <td>-1.021184</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>000913.SH</td>
#       <td>医药</td>
#       <td>-0.991790</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>HSCGSI.HI</td>
#       <td>恒生消费</td>
#       <td>-0.775402</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>601688.SH</td>
#       <td>华泰证券</td>
#       <td>-0.739106</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>HSIII.HI</td>
#       <td>恒生互联网</td>
#       <td>-0.720448</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>399814.SZ</td>
#       <td>农业</td>
#       <td>-0.644493</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>HSHK35.HI</td>
#       <td>恒生香港35</td>
#       <td>-0.636987</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>HSSCHI.HI</td>
#       <td>恒生港股通医疗</td>
#       <td>-0.570218</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>704843.MI</td>
#       <td>MSCI中国A股国际</td>
#       <td>-0.443407</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>133333.CSI</td>
#       <td>MSCI中国A股</td>
#       <td>-0.412605</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>FCHI.GI</td>
#       <td>法国CAC40</td>
#       <td>-0.400495</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>N225.GI</td>
#       <td>日经</td>
#       <td>-0.385098</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>HSHCI.HI</td>
#       <td>恒生医疗保健</td>
#       <td>-0.363144</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>718711L.MI</td>
#       <td>MSCI中国A股人民币</td>
#       <td>-0.315502</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>CES300.CSI</td>
#       <td>中华沪深港300</td>
#       <td>-0.309316</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>122489.MI</td>
#       <td>MSCI金龙</td>
#       <td>-0.224813</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>GDAXI.GI</td>
#       <td>德国DAX</td>
#       <td>-0.152853</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>HSSI.HI</td>
#       <td>恒生小型股</td>
#       <td>-0.099473</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>HSI.HI</td>
#       <td>恒生</td>
#       <td>-0.065178</td>
#     </tr>
#   </tbody>
# </table style="display:inline;margin-right:50px"><table style="display:inline;margin-right:50px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ticker</th>
#       <th>Name</th>
#       <th>DIVIDENDYIELD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>27</th>
#       <td>HSSCHI.HI</td>
#       <td>恒生港股通医疗</td>
#       <td>2.918265</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>HSHCI.HI</td>
#       <td>恒生医疗保健</td>
#       <td>2.723159</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>000913.SH</td>
#       <td>医药</td>
#       <td>2.337715</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>704843.MI</td>
#       <td>MSCI中国A股国际</td>
#       <td>2.017068</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>718711L.MI</td>
#       <td>MSCI中国A股人民币</td>
#       <td>1.977434</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>399814.SZ</td>
#       <td>农业</td>
#       <td>1.932505</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>000300.SH</td>
#       <td>沪深300</td>
#       <td>1.849992</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>HSCAIT.HI</td>
#       <td>恒生A股龙头</td>
#       <td>1.702201</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>707717L.MI</td>
#       <td>MSCI中国A股质量</td>
#       <td>1.684399</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>133333.CSI</td>
#       <td>MSCI中国A股</td>
#       <td>1.662655</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>830009.XI</td>
#       <td>富时中国A50</td>
#       <td>1.595546</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>DJCN88.GI</td>
#       <td>道中88</td>
#       <td>1.517062</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>HSCGSI.HI</td>
#       <td>恒生消费</td>
#       <td>1.276043</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>302400.MI</td>
#       <td>MSCI中国(美元)</td>
#       <td>1.242381</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>CES300.CSI</td>
#       <td>中华沪深港300</td>
#       <td>1.116464</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>122489.MI</td>
#       <td>MSCI金龙</td>
#       <td>1.017135</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>HSHK35.HI</td>
#       <td>恒生香港35</td>
#       <td>0.982964</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>601688.SH</td>
#       <td>华泰证券</td>
#       <td>0.947217</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>HSMI.HI</td>
#       <td>恒生中型股</td>
#       <td>0.910592</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>HSIII.HI</td>
#       <td>恒生互联网</td>
#       <td>0.817498</td>
#     </tr>
#   </tbody>
# </table style="display:inline;margin-right:50px">
