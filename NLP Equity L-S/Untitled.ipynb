# %%
import os
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Define target directory
base_dir = os.getcwd()
model_dir = os.path.join(base_dir, "Models", "m2m100_1.2B")

# Ensure the directory exists
os.makedirs(model_dir, exist_ok=True)

# Hugging Face model name
model_name = "facebook/m2m100_1.2B"

print(f"Downloading {model_name} into {model_dir} ...")

# Download and save tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.save_pretrained(model_dir)

# Download and save model
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
model.save_pretrained(model_dir)

print("✅ Download complete. Model saved locally.")
# Out:
# Downloading facebook/m2m100_1.2B into C:\Users\Bill Yin\Documents\GitHub\Strategy Development\NLP Equity L-S\Models\m2m100_1.2B ...
# pytorch_model.bin:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
