# %%
import numpy as np
import pandas as pd
from google.colab import drive
import os

# %%
drive.mount('/content/drive', force_remount=True)

drive_path = '/content/drive/MyDrive/Event Log/2025-7-28 申毅实习/策略研究/NLP 日度'
os.chdir(drive_path)
# Out:
# Mounted at /content/drive

# %%
equity_reports = pd.read_csv(
    'equity_reports.csv',
    encoding='utf-8',
    parse_dates=['PUBLISH_DATE', 'UPDATE_TIME', 'UPDATE_DATE']
)

# %%
report_ids = [
    4505756, 4505757, 4505758, 4505759, 4505760, 4505761, 4505762, 4505763, 4505764, 4505765,
    4505766, 4505767, 4505768, 4505769, 4505770, 4505771, 4505772, 4505773, 4505774, 4505775,
    4507175, 4507176, 4507177, 4507178, 4507179, 4507180, 4507181, 4507182, 4507183, 4507184,
    4507185, 4507186, 4507187, 4507188, 4507189, 4507190, 4507191, 4507192, 4507193,
    4509523, 4509524, 4509525, 4509526, 4509527, 4509528, 4509529, 4509530, 4509531, 4509532,
    4509533, 4509534, 4509535, 4509536, 4509537, 4509538, 4509539, 4509540, 4509541, 4509542,
    4510606, 4510607, 4510608, 4510609, 4510610, 4510611, 4510612, 4510613, 4510614, 4510615,
    4510616, 4510617, 4510618, 4510619, 4510620, 4510621, 4510622, 4510623, 4510624
]

filtered = equity_reports[equity_reports['REPORT_ID'].isin(report_ids)]

all_nan = filtered['SUMMARY'].isna().all()

print("All SUMMARY are NaN?" , all_nan)
# Out:
# All SUMMARY are NaN? True

# %%
import numpy as np
import pandas as pd
from google.colab import drive
import os

drive.mount('/content/drive', force_remount=True)

drive_path = '/content/drive/MyDrive/Event Log/2025-7-28 申毅实习/策略研究/NLP 日度'
os.chdir(drive_path)

sentiment_output = pd.read_csv('sentiment_output.csv')
len(sentiment_output)
# Out:
# Mounted at /content/drive
# 23922
