# %% [markdown]
# <a href="https://colab.research.google.com/github/Billy-Drunkenstein/Strategy_Concepts/blob/main/IBKR%20Paper/%E5%8F%8C%E5%9D%87%E7%BA%BF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ib-insync
# !pip install ibapi
# Out:
# Requirement already satisfied: ib-insync in /usr/local/lib/python3.11/dist-packages (0.9.86)
# Requirement already satisfied: eventkit in /usr/local/lib/python3.11/dist-packages (from ib-insync) (1.0.3)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ib-insync) (1.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from eventkit->ib-insync) (1.26.4)
# Collecting ibapi
#   Downloading ibapi-9.81.1.post1.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ibapi
#   Building wheel for ibapi (setup.py) ... done
#   Created wheel for ibapi: filename=ibapi-9.81.1.post1-py3-none-any.whl size=67943 sha256=f848cfd378a2357fa1fb8bb54841706329c6c7fe9f2e51cc2fff3611aeae3a52
#   Stored in directory: /root/.cache/pip/wheels/da/13/2b/1bf49acd2509e17f0a89926c3214b5de879ab6f223d27ded38
# Successfully built ibapi
# Installing collected packages: ibapi
# Successfully installed ibapi-9.81.1.post1

# %%
import numpy as np
import pandas as pd

# %%
import ibapi
print(ibapi.__version__)
# Out:
# 9.81.1-1

# %%
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract
from ibapi.order import Order
from ibapi.common import BarData

# %% [markdown]
# # Strategy Config

# %%
short_period = 5
long_period = 10

Tickers = {
    'SPY': 'S&P 500 Index',
    'XLY': 'Consumer Discretionary',
    'XLE': 'Energy',
    'XLV': 'Health Care',
    'XLK': 'Technology',
    'XLC': 'Communication Services',
    'XLP': 'Consumer Staples',
    'XLF': 'Financials',
    'XLI': 'Industrials',
    'XLB': 'Materials',
    'XLU': 'Utilities',
    'XLRE': 'Real Estate',
}

# %% [markdown]
# # DMA Class

# %%
class DMA(EClient, EWrapper):

    def __init__(self):
        EClient.__init__(self, self)
        self.data = []
