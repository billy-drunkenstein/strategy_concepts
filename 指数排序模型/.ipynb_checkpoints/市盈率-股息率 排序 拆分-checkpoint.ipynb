# %%
import pandas as pd
import numpy as np
import datetime
import json
import os
from IPython.display import display_html
from IPython.display import HTML

# %%
def display_horizontal(*args):
    html_str = ''
    for df in args:
        html_str += df.to_html()
    display_html(
        html_str.replace('table','table style="display:inline;margin-right:50px"'), 
        raw=True
    )

# %%
with open("INDEX_START.json", "r", encoding="utf-8") as f:
    INDEX_START = json.load(f)
    
with open("INDEX_NAME.json", 'r', encoding = 'utf-8') as f:
    INDEX_NAME = json.load(f)

# %%
INDEX_DATA = {}

for ticker in INDEX_START:
    path = f"Data/{ticker}.csv"
    
    if os.path.isfile(path): 
        data = pd.read_csv(path, index_col = 0, parse_dates = True)
        data.index = pd.to_datetime(data.index, format="%Y-%m-%d", errors='coerce')
        data.index = data.index.date
        INDEX_DATA[ticker] = data.copy(deep = True)

# %%
UNIVERSE = {}
target_dates = {}
today_date = datetime.datetime(2025, 4, 28)

for ticker in INDEX_DATA:
    target_dates[ticker] = INDEX_DATA[ticker].index[-1]

UNIVERSE = INDEX_DATA

# %%
print(f"Assets under Analysis: {len(UNIVERSE)}")
print(f"Total Assets: {len(INDEX_DATA)}")
# Out:
# Assets under Analysis: 186
# Total Assets: 186

# %% [markdown]
# ## Z Score Calculation

# %%
Z_PE_TTM = {}
Z_DIVIDENDYIELD = {}
years = 3
duration = years * 250

for ticker in UNIVERSE:
    target_date = target_dates[ticker]
    if len(UNIVERSE[ticker]) < duration:
        continue
    
    # PE TTM 分位值
    sample_data = UNIVERSE[ticker]['PE_TTM'].loc[:target_date].iloc[-duration:]
    assert len(sample_data) == duration
    
    mean = sample_data.mean()
    std = sample_data.std()
    
    Z = (UNIVERSE[ticker].loc[target_date, "PE_TTM"] - mean) / std
    
    Z_PE_TTM[ticker] = Z
    
    
    # 股息率 分位值
    sample_data = UNIVERSE[ticker]['DIVIDENDYIELD2'].loc[:target_date].iloc[-duration:]
    assert len(sample_data) == duration
    
    mean = sample_data.mean()
    std = sample_data.std()
    
    Z = (UNIVERSE[ticker].loc[target_date, 'DIVIDENDYIELD2'] - mean) / std
    
    Z_DIVIDENDYIELD[ticker] = Z

# %%
display_number = 30

df_Z_PE_TTM = pd.DataFrame(list(Z_PE_TTM.items()), columns=['Ticker', '市盈率'])
df_Z_DIVIDENDYIELD = pd.DataFrame(list(Z_DIVIDENDYIELD.items()), columns=['Ticker', '股息率'])

# Sort the dataframes
df_Z_PE_TTM_sorted = df_Z_PE_TTM.sort_values(by='市盈率', ascending=True)
df_Z_DIVIDENDYIELD_sorted = df_Z_DIVIDENDYIELD.sort_values(by='股息率', ascending=False)

# Display the top 10 sorted rows
top_Z_PE_TTM = df_Z_PE_TTM_sorted.head(display_number).copy()
top_Z_DIVIDENDYIELD = df_Z_DIVIDENDYIELD_sorted.head(display_number).copy()

top_Z_PE_TTM.loc[:, "指数名称"] = top_Z_PE_TTM["Ticker"].map(INDEX_NAME)
top_Z_PE_TTM = top_Z_PE_TTM[["Ticker", "指数名称", "市盈率"]]

top_Z_DIVIDENDYIELD.loc[:, "指数名称"] = top_Z_DIVIDENDYIELD["Ticker"].map(INDEX_NAME)
top_Z_DIVIDENDYIELD = top_Z_DIVIDENDYIELD[["Ticker", "指数名称", "股息率"]]

# %%
print()
print(f"{INDEX_DATA['000300.SH'].index[-1].strftime('%Y-%m-%d')}")
print(f"{years}年")
display_horizontal(top_Z_PE_TTM, top_Z_DIVIDENDYIELD)
print()
# Out:
# 2025-04-28
# 3年
# <table style="display:inline;margin-right:50px" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ticker</th>
#       <th>指数名称</th>
#       <th>市盈率</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>65</th>
#       <td>399812.SZ</td>
#       <td>养老产业</td>
#       <td>-2.066540</td>
#     </tr>
#     <tr>
#       <th>163</th>
#       <td>931250.CSI</td>
#       <td>港股创新药50</td>
#       <td>-1.798210</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>h30588.CSI</td>
#       <td>中证证保</td>
#       <td>-1.776294</td>
#     </tr>
#     <tr>
#       <th>140</th>
#       <td>399966.SZ</td>
#       <td>中证800证保</td>
#       <td>-1.753320</td>
#     </tr>
#     <tr>
#       <th>114</th>
#       <td>h30035.CSI</td>
#       <td>300非银</td>
#       <td>-1.736465</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>h30344.CSI</td>
#       <td>健康产业</td>
#       <td>-1.481871</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>601688.SH</td>
#       <td>华泰证券</td>
#       <td>-1.253725</td>
#     </tr>
#     <tr>
#       <th>127</th>
#       <td>931068.CSI</td>
#       <td>消费龙头</td>
#       <td>-1.230853</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>931027.CSI</td>
#       <td>港股通大消费</td>
#       <td>-1.157075</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>931573.CSI</td>
#       <td>港股科技50</td>
#       <td>-1.141211</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>931573CNY00.CSI</td>
#       <td>港股通科技CNY</td>
#       <td>-1.141211</td>
#     </tr>
#     <tr>
#       <th>126</th>
#       <td>931079.CSI</td>
#       <td>5G通信</td>
#       <td>-1.140786</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>931787CNY00.CSI</td>
#       <td>港股创新药</td>
#       <td>-1.125247</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>931024.CSI</td>
#       <td>港股非银</td>
#       <td>-1.121047</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>000815.CSI</td>
#       <td>细分食品</td>
#       <td>-1.112060</td>
#     </tr>
#     <tr>
#       <th>131</th>
#       <td>930653.CSI</td>
#       <td>CS食品饮</td>
#       <td>-1.104759</td>
#     </tr>
#     <tr>
#       <th>125</th>
#       <td>931139.CSI</td>
#       <td>CS消费50</td>
#       <td>-1.099395</td>
#     </tr>
#     <tr>
#       <th>171</th>
#       <td>TPX.GI</td>
#       <td>日本东证指数</td>
#       <td>-1.091541</td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>931454.CSI</td>
#       <td>港股消费易方达</td>
#       <td>-1.091283</td>
#     </tr>
#     <tr>
#       <th>161</th>
#       <td>930965.CSI</td>
#       <td>港股通医药</td>
#       <td>-1.078333</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>122489.MI</td>
#       <td>MSCI金龙</td>
#       <td>-1.059106</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>931526.CSI</td>
#       <td>企业核心竞争力50</td>
#       <td>-1.021470</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>931637.CSI</td>
#       <td>港股通互联网</td>
#       <td>-0.995437</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>932307.CSI</td>
#       <td>中国互联网人民币中间价</td>
#       <td>-0.948723</td>
#     </tr>
#     <tr>
#       <th>167</th>
#       <td>987018.CNI</td>
#       <td>港股通创新药</td>
#       <td>-0.935150</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>707717L.MI</td>
#       <td>MSCI中国A股质量</td>
#       <td>-0.899392</td>
#     </tr>
#     <tr>
#       <th>152</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>146</th>
#       <td>930928.CSI</td>
#       <td>CR新动能</td>
#       <td>1.699279</td>
#     </tr>
#   </tbody>
# </table style="display:inline;margin-right:50px">

# %% [markdown]
# durations = [3, 5]
#
# for years in durations:
#     Z_PE_TTM = {}
#     Z_DIVIDENDYIELD = {}
#     target_date = INDEX_DATA['000300.SH'].index[-1]
#     duration = years * 250
#
#     for ticker in UNIVERSE:
#         if len(UNIVERSE[ticker]) < duration:
#             continue
#
#         sample_data = UNIVERSE[ticker]['PE_TTM'].loc[:target_date].iloc[-duration:]
#         assert len(sample_data) == duration
#
#         mean = sample_data.mean()
#         std = sample_data.std()
#
#         Z = (UNIVERSE[ticker].loc[target_date, "PE_TTM"] - mean) / std
#
#         if std == 0:
#             print(ticker, duration, len(sample_data))
#
#         Z_PE_TTM[ticker] = Z
#
#
#         sample_data = UNIVERSE[ticker]['DIVIDENDYIELD2'].loc[:target_date].iloc[-duration:]
#         assert len(sample_data) == duration
#
#         mean = sample_data.mean()
#         std = sample_data.std()
#
#         Z = (UNIVERSE[ticker].loc[target_date, 'DIVIDENDYIELD2'] - mean) / std
#
#         Z_DIVIDENDYIELD[ticker] = Z
#
#
#     display_number = 20
#
#     df_Z_PE_TTM = pd.DataFrame(list(Z_PE_TTM.items()), columns=['Ticker', '市盈率'])
#     df_Z_DIVIDENDYIELD = pd.DataFrame(list(Z_DIVIDENDYIELD.items()), columns=['Ticker', '股息率'])
#
#     # Sort the dataframes
#     df_Z_PE_TTM_sorted = df_Z_PE_TTM.sort_values(by='市盈率', ascending=True)
#     df_Z_DIVIDENDYIELD_sorted = df_Z_DIVIDENDYIELD.sort_values(by='股息率', ascending=False)
#
#     # Display the top 10 sorted rows
#     top_Z_PE_TTM = df_Z_PE_TTM_sorted.head(display_number).copy()
#     top_Z_DIVIDENDYIELD = df_Z_DIVIDENDYIELD_sorted.head(display_number).copy()
#
#     top_Z_PE_TTM.loc[:, "指数名称"] = top_Z_PE_TTM["Ticker"].map(INDEX_NAME)
#     top_Z_PE_TTM = top_Z_PE_TTM[["Ticker", "指数名称", "市盈率"]]
#
#     top_Z_DIVIDENDYIELD.loc[:, "指数名称"] = top_Z_DIVIDENDYIELD["Ticker"].map(INDEX_NAME)
#     top_Z_DIVIDENDYIELD = top_Z_DIVIDENDYIELD[["Ticker", "指数名称", "股息率"]]
#
#
#     print()
#     print(f"{INDEX_DATA['000300.SH'].index[-1].strftime('%Y-%m-%d')}")
#     print(f"{years}年")
#     display_horizontal(top_Z_PE_TTM, top_Z_DIVIDENDYIELD)
#     print()

# %%
from wcwidth import wcswidth

def pad_display(s, width):
    """Pad string s to display width = width, accounting for wide chars like Chinese."""
    pad_len = width - wcswidth(s)
    return s + ' ' * max(0, pad_len)

# Parameters
COLUMNS = 4
TICKER_WIDTH = 18
NAME_WIDTH = 25

items = sorted(INDEX_NAME.items())

for i in range(0, len(items), COLUMNS):
    row = items[i:i+COLUMNS]
    line = ""
    for ticker, name in row:
        line += pad_display(ticker, TICKER_WIDTH)
