# %%
from WindPy import w
import numpy as np
import pandas as pd
import datetime
import json
import copy
from tqdm import tqdm
import os

w.start()
w.isconnected()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2024 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# True

# %%
def ticker_generator(tickers):
    for ticker, name in tickers.items():
        yield ticker, name

# %%
with open("INDEX_START.json", "r", encoding="utf-8") as f:
    INDEX_START = json.load(f)

# %%
with open('INDEX_START.json', 'r', encoding = "utf-8") as f:
    Index_Start = json.load(f)

print(len(Index_Start))
# Out:
# 203

# %%
df = pd.read_csv("A股指数.csv")
a_share_dict = dict(zip(df["Ticker"], df["Name"]))

df = pd.read_csv("海外指数.csv")
other_market_dict = dict(zip(df["Ticker"], df["Name"]))

print(len(a_share_dict), len(other_market_dict))
# Out:
# 333 57

# %%
INDEX_DATA = {}

for ticker in INDEX_START:
    path = f"Data/{ticker}.csv"
    
    if os.path.isfile(path): 
        data = pd.read_csv(path, index_col = 0, parse_dates = True)
        data.index = pd.to_datetime(data.index, format="%Y-%m-%d", errors='coerce')
        data.index = data.index.date
        INDEX_DATA[ticker] = data.copy(deep = True)

print(len(INDEX_DATA))
# Out:
# 186

# %%
Tickers = {}

Tickers_1 = {
    'NDX.GI': '纳斯达克100',
    '000300.SH': '沪深300',
#    'NBI.GI': '纳指生物科技',
    'SPX.GI': '标普500',
    '000913.SH': '医药',
    '399814.SZ': '农业',
    'HSI.HI': '恒生',
    'DJSOEP.GI': '道琼斯石油',
    'HSTECH.HI': '恒生科技',
    'NDXTMC.GI': '纳指科技100',
    'GDAXI.GI': '德国DAX',
    'CSPSADRP.CI': '标普A股红利',
    '830009.XI': '富时中国A50',
    'N225.GI': '日经',
    '399975.SZ': '证券',
#    'YANG.P': 'Direxion3倍做空',
#    'YINN.P': 'Direxion3倍做多',
    '601688.SH': '华泰证券',
    'HSSCHKY.HI': '恒生高股息',
    'HXC.GI': '纳斯达克中国金龙',
    'HSHDYI.HI': 'GX恒生高股息率',
    'FCHI.GI': '法国CAC40',
#    'SPSIOPTR.SPI': '标普油气',
#    '931078.CSI': '可转债',
#    'SP5CSSUP.SPI': '标普消费',
    '931787CNY00.CSI': '港股创新药',
    'H30533.CSI': '中概互联网',
#    'VIX.GI': 'CBOE波动率',
    'HSIII.HI': '恒生互联网',
#    'CIS51001.WI': '印度基金',
#    'DWRTF.GI': '美国REIT精选',
    '931791.CSI': '中韩半导体',
#    'SPTAUUSDOZ.IDC': '伦敦金现货',
#    '930794.CSI': '中美互联网',
#    'SPGSCITR.SPI': '标普高盛商品总收益',
    'DJI.GI': '道琼斯工业平均',
    '750108.MI': 'MSCI美国50',
    'SOX.GI': '费城半导体',
#    'CHXN9000.GI': '纳指中国科技股',
#    '915800.MI': 'MSCI台湾',
#    'SPSIOPTR.SPI': '标普石油天然气上游股票全收益',
    'DJSOEP.GI': '道琼斯美国石油',
#    '891800.MI': 'MSCI新兴市场',
    '122489.MI': 'MSCI金龙',
#    'SPG120035.SPI': '标普全球1200医疗保健',
#    '990500.MI': 'MSCI欧洲',
#    '899903.MI': 'MSCI亚太地区(除日本)',
    'HSHKBIO.HI': '恒生生物科技',
    'HSHCI.HI': '恒生医疗保健',
#    '892400.MI': 'MSCI全球指数',
#    'SBPRGLU.SPI': '标普全球大中盘',
    'RUI.GI': '罗素1000',
#    'WISAUNT.FI': '富时沙特阿拉伯',
#    'SP5CSSUP.SPI': '标普500消费精选',
#    '128456.MI': 'MSCI US REIT',
}

Tickers_2 = {
    "SPCLLHCP.SPI": "标普中国A50红利低波",
    "707918.MI": "MSCI中国A股低波(美元)",
    "746059.MI": "MSCI中国A50互联",
    "718711L.MI": "MSCI中国A股人民币",
    "716567.MI": "MSCI中国A股国际(美元)",
    "704843.MI": "MSCI中国A股国际",
    "133333.CSI": "MSCI中国A股",
    "HSCAIT.HI": "恒生A股龙头",
    "HSSCHI.HI": "恒生港股通医疗",
    "HSHCI.HI": "恒生医疗",
    "DJCN88.GI": "道中88",
    "707717L.MI": "MSCI中国A股质量",
    "830009.XI": "富时中国A50",
    "HSSSHID.HI": "恒生创新药50",
    "302400.MI": "MSCI中国(美元)",
    "HSSSCHD.HI": "恒生高股息",
    "HSSI.HI": "恒生小型股",
    "CES300.CSI": "中华沪深港300",
    "HSCGSI.HI": "恒生消费",
    "HSHKBIO.HI": "恒生生科",
    "CSPSADRP.CI": "标普A股红利",
    "HSSCT.HI": "恒生中国科技",
    "HSMI.HI": "恒生中型股",
    "HSSCNE.HI": "恒生新经济",
    "HSHYLV.HI": "恒生高息低波",
    "CESFHY.CSI": "中华高息",
    "GPCCH003.FI": "富时中国央企",
    "HSCSOE.HI": "恒生央企",
    "HSIII.HI": "恒生互联网科技",
    "HSTECH.HI": "恒生科技",
    "HSMCHYI.HI": "恒生内地企业高息",
    "HSSCSOY.HI": "恒生央企红利",
    "HSHK35.HI": "恒生香港35",
    "HSHDYI.HI": "恒生高息",
    "HSSCHKY.HI": "恒生高息",
    "HSBBAC.HI": "恒生大湾区",
    "HSCEI.HI": "恒生国企",
    "HSI.HI": "恒生指数",
    "HSINH.HI": "恒生NTR",
    "SPHCMSHP.SPI": "标普香港中小盘",
    "DJI.GI": "道琼斯工业",
    "CES100.CSI": "中华港股100",
    "SPX.GI": "标普500",
    "SPXEWTR.SPI": "标普500等权",
    "SPTR500N.SPI": "标普500净总回报",
    "S5INFT.SPI": "标普500信息科技",
    "HSISUI.HI": "恒指ESG增强精选",
    "HSIESGS.HI": "恒指ESG",
    "HSFML25.HI": "恒生香港25",
    "990001.CSI": "中华半导体",
    "750108.MI": "MSCI美国50",
#     "WISAUNT.FI": "富时沙特",
#     "ERGLU.FI": "富时发达REITs",
#     "FIVNM30.FI": "富时越南30",
#     "GPCSP006.FI": "富时亚太低碳",
#     "830008.XI": "富时中国50",
#     "SP500-251020.SPI": "标普500汽车",
#     "991400.MI": "MSCI太平洋(除日本)",
#     "SPHYARUP.SPI": "标普高收益亚太REITs",
#     "721638.MI": "MSCI中国A ESG",
#     "105769.MI": "MSCI泰国",
#     "664181.MI": "MSCI新加坡",
#     "664241.MI": "MSCI菲律宾",
#     "HSCALCS.HI": "恒生A股低碳",
    "HSIDI.HI": "恒生创新药ETF",
    "HSIII.HI": "恒生互联网ETF",
    "HSISC.HI": "恒生港股通ETF",
    "HSMCHYI.HI": "恒生红利ETF",
    "HSSCHI.HI": "恒生医疗ETF",
    "HSSCHKY.HI": "港股红利ETF博时",
    "HSSCNE.HI": "恒生新经济ETF",
    "HSSCSOY.HI": "港股通央企红利ETF",
    "HSSCT.HI": "港股科技30ETF",
    "HSTECH.HI": "恒生科技ETF基金",
    "N225.GI": "日经225ETF",
    "NBI.GI": "纳指生物科技ETF",
    "NDX.GI": "纳斯达克指数ETF",
    "NDXTMC.GI": "纳指科技ETF",
    "SP5CSSUP.SPI": "标普消费ETF",
    "SPAHLVCP.SPI": "港股红利指数ETF",
    "SPNCSCHN.SPI": "新经济ETF",
    "SPSIBI.SPI": "标普生物科技ETF",
    "SPSIOPTR.SPI": "标普油气ETF",
    "SPTR500N.SPI": "标普500ETF",
    "SPX.GI": "标普500ETF南方",
    "TPX.GI": "日本东证指数ETF",
    "WISAUNT.FI": "沙特ETF"
}

len(Tickers_4)

# %%
# Tickers = copy.deepcopy(Tickers_1)

# for ticker, name in Tickers_2.items():
#     if ticker not in Tickers:
#         Tickers[ticker] = name

# for ticker, name in Tickers_3.items():
#     if ticker not in Tickers:
#         Tickers[ticker] = name

# for ticker, name in Tickers_4.items():
#     if ticker not in Tickers:
#         Tickers[ticker] = name

# len(Tickers)

# %%
Tickers = other_market_dict

# %%
new_Tickers = {
'CSPSADRP.CI': '标普A股红利',
'746059.MI': 'MSCI中国A50互联互通',
'930941.CSI': 'CME商品(CNY)',
'128456.MI': 'MSCI US REIT INDEX',
'750108.MI': 'MSCI美国50指数',
'MSCI Europe Index': 'MSCI欧洲净收益指数',
'899903.MI': 'MSCI亚太地区(除日本)',
'707717L.MI': 'MSCI中国A股国际质量指数',
'CL.NYM': 'NYMEX WTI原油价格',
'Au9999.SGE': 'SGE黄金9999',
'884215.WI': '比特币',
'SPOEXEUP.SPI': '标普100等权重指数',
'SPX.GI': '标普500',
'SP500EW-35.SPI': '标普500等权重医疗保健行业',
'SPXEWTR.SPI': '标普500等权重指数',
'SPTR500N.SPI': '标普500净总回报',
'SPN.SPI': '标普500能源',
'SP5CSSUP.SPI': '标普500消费精选',
'S5INFT.SPI': '标普500信息科技',
'SPAHLVCP.SPI': '标普港股通低波红利指数',
'SPGSCITR.SPI': '标普高盛商品全收益指数',
'SPGSCLP.SPI': '标普高盛原油超额收益指数',
'IXY.SPI': '标普可选消费品精选行业指数',
'SPG120035.SPI': '标普全球1200医疗保健行业',
'S&P Global Mining&Energy Index': '标普全球矿产及能源指数',
'SPGOGUP.SPI': '标普全球石油指数',
'SPSIBI.SPI': '标普生物技术精选行业',
'SPSIOPTR.SPI': '标普石油天然气上游股票',
'SPHCMSHP.SPI': '标普香港上市中国中小盘精选',
'SPCLLHCP.SPI': '标普中国A股大盘红利低波50',
'SPNCSCHN.SPI': '标普中国新经济行业',
'DJI.GI': '道琼斯工业指数',
'DWRTF.GI': '道琼斯美国精选REIT',
'DJSOEP.GI': '道琼斯美国石油开发与生产',
'GDAXI.GI': '德国DAX',
'TPX.GI': '东证指数',
'FCHI.GI': '法国CAC40',
'SOX.GI': '费城半导体指数',
'ERGLU.FI': '富时发达市场REITs',
'WISAUNT.FI': '富时沙特(里亚尔)(净总回报)',
'GPCSP006.FI': '富时亚太低碳精选指数',
'830009.XI': '富时中国A50',
'888888.FI': '富时中国A股自由现金流',
'931787CNY00.CSI': '港股创新药(CNY)',
'930839.CSI': '港股通高息精选',
'987008.CNI': '港股通科技',
'HSIDI.HI': '恒生创新药',
'HSSCID.HI': '恒生港股通创新药',
'HSSSHID.HI': '恒生沪深港创新药50',
'HSTECH.HI': '恒生科技',
'HSSI.HI': '恒生小型股',
'HSI.HI': '恒生指数',
'SPTAUUSDOZ.IDC': '伦敦金现 ',
'RLG.GI': '罗素1000成长指数',
'NDX.GI': '纳斯达克100',
'XNDX.O': '纳斯达克100全收益',
'NDXTMC.GI': '纳斯达克科技市值加权',
'NBI.GI': '纳斯达克生物技术',
'HXC.GI': '纳斯达克中国金龙',
'STOXX® Global 1800 REITs Index': '诺安全球不动产',
'SPGLGUP.SPI': '全球高端消费品',
'930796.CSI': '全球中国互联网(CNY)',
'N225.GI': '日经225',
'ASIATECP.GI': '新交所泛东南亚科技指数',
'EMASIAUP.GI': '新交所新兴亚洲精选50',
'伦敦现货黄金*50%+(MSCI ACWI SELECT GOLD MINERSIMI INDEX)*50%': '以伦敦黄金价+MSCI全球金矿股指数',
'FTSE.GI': '英国富时100',
'WTI*60%+BRENT*40%': '原油商品价格',
'930604.CSI': '中国互联网30',
'931790.CSI': '中韩半导体',
'CIS51001.WI': '中信证券印度ETP指数',}

# %%
datetime_threshold = datetime.datetime(2014, 1, 1)

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# # Official Launch Date

# %%
existing_tickers = {}
additional_tickers = {}
for ticker in new_Tickers:
    if ticker not in INDEX_DATA:
        additional_tickers[ticker] = new_Tickers[ticker]

    else:
        existing_tickers[ticker] = new_Tickers[ticker]

len(additional_tickers), len(existing_tickers)
# Out:
# (39, 32)

# %%
additional_ticker_start = {}

# %%
for ticker in tqdm(additional_tickers):
    launch_date = w.wss(ticker, "fund_setupdate").Data[0][0]
    if launch_date < datetime_threshold:
        additional_ticker_start[ticker] = datetime_threshold
    else: 
        additional_ticker_start[ticker] = launch_date
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 39/39 [00:21<00:00,  1.85it/s]

# %%
len(additional_ticker_start)
# Out:
# 39

# %%
for ticker in additional_ticker_start:
    launch_date = additional_ticker_start[ticker]
    additional_ticker_start[ticker] = launch_date.strftime("%Y-%m-%d")

# %%
len(additional_ticker_start), len(additional_tickers)
# Out:
# (39, 39)

# %%
for ticker in additional_tickers:
    if ticker not in Index_Start:
        print(ticker)
# Out:
# 930941.CSI
# 128456.MI
# MSCI Europe Index
# 899903.MI
# CL.NYM
# Au9999.SGE
# SPOEXEUP.SPI
# SP500EW-35.SPI
# SP5CSSUP.SPI
# SPAHLVCP.SPI
# SPGSCITR.SPI
# SPGSCLP.SPI
# IXY.SPI
# SPG120035.SPI
# S&P Global Mining&Energy Index
# SPGOGUP.SPI
# SPSIBI.SPI
# SPSIOPTR.SPI
# SPNCSCHN.SPI
# DWRTF.GI
# ERGLU.FI
# WISAUNT.FI
# GPCSP006.FI
# SPTAUUSDOZ.IDC
# RLG.GI
# NBI.GI
# STOXX® Global 1800 REITs Index
# SPGLGUP.SPI
# ASIATECP.GI
# EMASIAUP.GI
# 伦敦现货黄金*50%+(MSCI ACWI SELECT GOLD MINERSIMI INDEX)*50%
# WTI*60%+BRENT*40%
# CIS51001.WI

# %% [markdown]
# <br><br>

# %% [markdown]
# # Data Availability Date

# %%
gen = ticker_generator(additional_tickers)
added_tickers = []
added_ticker_start = {}

# %%
ticker, name = next(gen)
ticker, name = ticker, new_Tickers[ticker]

start = additional_ticker_start[ticker]
end = (datetime.datetime.strptime(start, "%Y-%m-%d") + datetime.timedelta(days=10)).strftime("%Y-%m-%d")

data = w.wsd(ticker, 'pe_ttm,dividendyield2,close', start, end, '', usedf = True)[1]

print(name, ticker, start)
print(data)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[606], line 1
# ----> 1 ticker, name = next(gen)
#       2 ticker, name = ticker, new_Tickers[ticker]
#       4 start = additional_ticker_start[ticker]
#
# StopIteration:

# %%
print(name, ticker, start)
data = w.wsd(ticker, 'pe_ttm,dividendyield2,close', '2025-05-21', '2025-05-23', '', usedf = True)[1]
data
# Out:
# 中信证券印度ETP指数 CIS51001.WI 2017-12-14
#             PE_TTM  DIVIDENDYIELD2      CLOSE
# 2025-05-21     NaN             NaN  2071.0127
# 2025-05-22     NaN             NaN  2055.9653
# 2025-05-23     NaN             NaN  2082.3499

# %%
print(name, ticker)

start = additional_ticker_start[ticker]
# start = "2014-01-01"
end = (datetime.datetime.strptime(start, "%Y-%m-%d") + datetime.timedelta(days=10)).strftime("%Y-%m-%d")
data = w.wsd(ticker, 'pe_ttm,dividendyield2,close', start, end, '', usedf = True)[1]

while data.isna().sum().sum() != 0:
    start = (datetime.datetime.strptime(start, "%Y-%m-%d") + datetime.timedelta(days=30)).strftime("%Y-%m-%d")
    end = (datetime.datetime.strptime(start, "%Y-%m-%d") + datetime.timedelta(days=10)).strftime("%Y-%m-%d")
    data = w.wsd(ticker, 'pe_ttm,dividendyield2,close', start, end, '', usedf = True)[1]
    print(start)

print(data)
# Out:
# 恒生港股通创新药 HSSCID.HI
# 2023-08-09
# 2023-09-08
# 2023-10-08
# 2023-11-07
# 2023-12-07
# 2024-01-06
# 2024-02-05
# 2024-03-06
# 2024-04-05
# 2024-05-05
# 2024-06-04
# 2024-07-04
# 2024-08-03
# 2024-09-02
# 2024-10-02
#                PE_TTM  DIVIDENDYIELD2    CLOSE
# 2024-10-08  42.364498          1.1572  2255.77
# 2024-10-09  41.297699          1.1909  2188.25
# 2024-10-10  41.749599          1.1724  2215.69
# 2024-10-11  41.749599          1.1724  2215.69

# %%
ticker in Index_Start
# Out:
# True

# %%
ticker in other_market_dict
# Out:
# False

# %%
start, Index_Start[ticker]
# Out:
# ('2014-01-01', '2014-01-01')

# %%
added_tickers.append(ticker)
added_ticker_start[ticker] = start
print(added_tickers)
# Out:
# ['884215.WI', 'SPN.SPI', '888888.FI', 'HSSCID.HI', 'XNDX.O', 'FTSE.GI']

# %%
Index_Start[ticker] = start

# %%
# Index_Start[ticker] = '2014-01-01'

# %%
len(Index_Start)
# Out:
# 203

# %%
for ticker in additional_ticker_start:
    if ticker not in added_tickers:
        print(ticker, new_Tickers[ticker])
# Out:
# 930941.CSI CME商品(CNY)
# 128456.MI MSCI US REIT INDEX
# MSCI Europe Index MSCI欧洲净收益指数
# 899903.MI MSCI亚太地区(除日本)
# Au9999.SGE SGE黄金9999
# SPOEXEUP.SPI 标普100等权重指数
# SP500EW-35.SPI 标普500等权重医疗保健行业
# SP5CSSUP.SPI 标普500消费精选
# SPGSCITR.SPI 标普高盛商品全收益指数
# SPGSCLP.SPI 标普高盛原油超额收益指数
# IXY.SPI 标普可选消费品精选行业指数
# SPG120035.SPI 标普全球1200医疗保健行业
# S&P Global Mining&Energy Index 标普全球矿产及能源指数
# SPGOGUP.SPI 标普全球石油指数
# ERGLU.FI 富时发达市场REITs
# RLG.GI 罗素1000成长指数
# STOXX® Global 1800 REITs Index 诺安全球不动产
# SPGLGUP.SPI 全球高端消费品
# 伦敦现货黄金*50%+(MSCI ACWI SELECT GOLD MINERSIMI INDEX)*50% 以伦敦黄金价+MSCI全球金矿股指数
# WTI*60%+BRENT*40% 原油商品价格
# CIS51001.WI 中信证券印度ETP指数
# CL.NYM NYMEX WTI原油价格
# SPAHLVCP.SPI 标普港股通低波红利指数
# SPSIBI.SPI 标普生物技术精选行业
# SPSIOPTR.SPI 标普石油天然气上游股票
# SPNCSCHN.SPI 标普中国新经济行业
# DWRTF.GI 道琼斯美国精选REIT
# WISAUNT.FI 富时沙特(里亚尔)(净总回报)
# GPCSP006.FI 富时亚太低碳精选指数
# SPTAUUSDOZ.IDC 伦敦金现
# NBI.GI 纳斯达克生物技术
# ASIATECP.GI 新交所泛东南亚科技指数
# EMASIAUP.GI 新交所新兴亚洲精选50

# %%
to_xlsx = {}
for ticker in added_tickers:
    to_xlsx[ticker] = new_Tickers[ticker]

# %%
df = pd.DataFrame(to_xlsx.items(), columns = ['代码', '名称'])
df.to_excel("新增指数.xlsx", index = False)

# %%
with open('INDEX_START.json', 'w', encoding = 'utf-8') as f:
    json.dump(Index_Start, f, indent = 4)

# %%
len(Index_Start)

# %%
Index_Name = {}
for ticker in Tickers:
    if ticker in Index_Start:
        Index_Name[ticker] = Tickers[ticker]

# %%
with open('INDEX_NAME.json', 'w', encoding = 'utf-8') as f:
    json.dump(Index_Name, f, indent = 4)

# %%
deleted_ticker
# Out:
# ['WISAUNT.FI',
#  'SPTAUUSDOZ.IDC',
#  'SPSIOPTR.SPI',
#  'SPSIBI.SPI',
#  'SPNCSCHN.SPI',
#  'SPAHLVCP.SPI',
#  'NBI.GI',
#  'IMCI.SHF',
#  'GPCSP006.FI',
#  'EMASIAUP.GI',
#  'DWRTF.GI',
#  'CL.NYM',
#  'CIS5001.WI',
#  'B.IPE',
#  'ASIATECP.GI']

# %%
'SP6CSSUP.SPI' in deleted_ticker
# Out:
# False

# %%
deleted_ticker
# Out:
# ['WISAUNT.FI',
#  'SPTAUUSDOZ.IDC',
#  'SPSIOPTR.SPI',
#  'SPSIBI.SPI',
#  'SPNCSCHN.SPI',
#  'SPAHLVCP.SPI',
#  'NBI.GI',
#  'IMCI.SHF',
#  'GPCSP006.FI',
#  'EMASIAUP.GI',
#  'DWRTF.GI',
#  'CL.NYM',
#  'CIS5001.WI',
#  'B.IPE',
#  'ASIATECP.GI',
#  'SP6CSSUP.SPI']
